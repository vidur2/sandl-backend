# %%
from sentence_transformers import SentenceTransformer, util
import pandas as pd
from sklearn import preprocessing
from sklearn.metrics import confusion_matrix, classification_report,accuracy_score
from sklearn.svm import OneClassSVM

# %%
data = open("./metrics/parsed/out.csv",errors="ignore").read()
df = pd.Series(data.split("\n"))
X = []
device 
transformer = SentenceTransformer("all-MiniLM-L6-v2", device="mps")

# %%
out = df.apply(transformer.encode)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/vidurmodgil/Desktop/Data/Programming Projects/sandl_backend/model/training.ipynb Cell 3 line 1
# ----> <a href='vscode-notebook-cell:/Users/vidurmodgil/Desktop/Data/Programming%20Projects/sandl_backend/model/training.ipynb#X10sZmlsZQ%3D%3D?line=0'>1</a> out = df.apply(transformer.encode)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/series.py:4771, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4661 def apply(
#    4662     self,
#    4663     func: AggFuncType,
#    (...)
#    4666     **kwargs,
#    4667 ) -> DataFrame | Series:
#    4668     """
#    4669     Invoke function on values of Series.
#    4670
#    (...)
#    4769     dtype: float64
#    4770     """
# -> 4771     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# ...

# %%
one_svm = IsolationForest().fit(out)
y = ["Who was the president of the United States in 1901?"]
print(one_svm.predict(y))
